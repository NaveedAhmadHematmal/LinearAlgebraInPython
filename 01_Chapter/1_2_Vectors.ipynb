# %% [markdown]
# Vector drawing

# %%
from matplotlib import pyplot as pl

pl.grid()
pl.plot([1, 2], [3, 3])
pl.plot([1, 1.7], [2.5, 2.5])
pl.plot([1, 1], [1.5, 3])

# %%
from matplotlib import pyplot as pl

pl.grid()
pl.plot([1, 1.5], [1, 3])
pl.plot([1.5, 2], [3, 1])
pl.plot([1.19, 1.82], [1.75, 1.75])
